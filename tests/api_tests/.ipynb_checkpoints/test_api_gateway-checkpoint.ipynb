# %%
# Run environment setup first
# %run ../../environment_setup.ipynb  

# Import required libraries
import sys
import pytest
import httpx
from fastapi.testclient import TestClient

# Ensure API Gateway path is included
sys.path.append("C:/Users/Dell/OptiFlow/api_gateway")

# Import the FastAPI application
from api_gateway.api_gateway_entry import app  # Ensure this file exists!

# Create a TestClient instance
client = TestClient(app)

# Define test functions
def test_root():
    """Test root endpoint"""
    response = client.get("/")
    assert response.status_code == 200
    assert response.json() == {"message": "Welcome to OptiFlow API Gateway"}

def test_health_check():
    """Test health check endpoint"""
    response = client.get("/health")
    assert response.status_code == 200
    assert response.json() == {"status": "healthy"}

# Run tests
if __name__ == "__main__":
    pytest.main(["-q", "--disable-warnings"])
# Out:
# Starting API Gateway tests...
#
# Testing health check endpoint...
# Response: {'status': 'ok'}
# Health check passed!
#
# Testing create resource endpoint...
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7248\1859929632.py in <module>
#      50     print("Starting API Gateway tests...\n")
#      51     test_health_check()
# ---> 52     test_create_resource()
#      53     test_get_resources()
#      54     print("All tests completed successfully!")
#
# ~\AppData\Local\Temp\ipykernel_7248\1859929632.py in test_create_resource()
#      30     }
#      31     response = requests.post(f"{BASE_URL}/resources", json=data)
# ---> 32     assert response.status_code == 201, f"Expected 201, got {response.status_code}"
#      33     print("Response:", response.json())
#      34     assert "id" in response.json(), "Missing 'id' in response"
#
# AssertionError: Expected 201, got 404
