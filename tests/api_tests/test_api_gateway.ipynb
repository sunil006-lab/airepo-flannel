# %%
# Run environment setup first
# %run ../../environment_setup.ipynb  

# Import required libraries
import sys
import pytest
import httpx
from fastapi.testclient import TestClient

# Ensure API Gateway path is included
sys.path.append("C:/Users/Dell/OptiFlow/api_gateway")

# Import the FastAPI application
from api_gateway.api_gateway_entry import app  # Ensure this file exists!

# Create a TestClient instance
client = TestClient(app)

# Define test functions
def test_root():
    """Test root endpoint"""
    response = client.get("/")
    assert response.status_code == 200
    assert response.json() == {"message": "Welcome to OptiFlow API Gateway"}

def test_health_check():
    """Test health check endpoint"""
    response = client.get("/health")
    assert response.status_code == 200
    assert response.json() == {"status": "healthy"}

# Run tests
if __name__ == "__main__":
    pytest.main(["-q", "--disable-warnings"])
# Out:
#  Python Path Updated: ['C:\\Users\\Dell\\OptiFlow\\tests', 'C:\\Users\\Dell\\OptiFlow', 'C:\\Users\\Dell\\OptiFlow\\tests\\api_tests', 'D:\\Anaconda3\\python39.zip', 'D:\\Anaconda3\\DLLs', 'D:\\Anaconda3\\lib', 'D:\\Anaconda3', '', 'C:\\Users\\Dell\\AppData\\Roaming\\Python\\Python39\\site-packages', 'D:\\Anaconda3\\lib\\site-packages', 'D:\\Anaconda3\\lib\\site-packages\\win32', 'D:\\Anaconda3\\lib\\site-packages\\win32\\lib', 'D:\\Anaconda3\\lib\\site-packages\\Pythonwin', 'D:\\Anaconda3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\Dell\\.ipython']
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7248\2992400464.py in <module>
#      12
#      13 # Import the FastAPI application
# ---> 14 from api_gateway.api_gateway_entry import app  # Ensure this file exists!
#      15
#      16 # Create a TestClient instance
#
# ...
